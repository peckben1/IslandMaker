# %%
import matplotlib.pyplot as plt, matplotlib.image as mpimg, seaborn as sns, pandas as pd, numpy as np, noise

# %%
from skimage.morphology import (disk, ball)

# %%
shape = (101,101)
scale = 100.0
octaves = 6
persistence = 0.5
lacunarity = 2.0

world = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        world[i][j] = noise.pnoise2(i/scale, 
                                    j/scale, 
                                    octaves=octaves, 
                                    persistence=persistence, 
                                    lacunarity=lacunarity, 
                                    repeatx=1024, 
                                    repeaty=1024, 
                                    base=0)
        
plt.imshow(world)
plt.colorbar();

# %%
#world

# %%
r = 50

# %%
bosco = ball(r)

# %%
#bosco[3]

# %%
biscotti = np.sum(bosco, axis=1)/(r*5)

# %%
#biscotti

# %%
plt.imshow(biscotti)
plt.colorbar();

# %%
plt.imshow(world+biscotti)
plt.colorbar();

# %%
biscuit_land = world+biscotti

# %%
flood = np.max(biscuit_land)/2
flood
# Out:
# 0.24695197117328643

# %%
for i in range(len(biscuit_land)):
    for j in range(len(biscuit_land)):
        if biscuit_land[i][j] < flood:
            biscuit_land[i][j] = 0

# %%
plt.imshow(biscuit_land)
